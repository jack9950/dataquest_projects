# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button

# %%
x = [1, 2, 3]
y = np.array([[1, 2], [3, 4], [5, 6]])
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd30c774910>,
#  <matplotlib.lines.Line2D at 0x7fd2dc5fc3a0>]

# %%
y.shape
# Out:
# (3, 2)

# %%
plt.plot(x, y, 'bo-')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd2dc4140a0>,
#  <matplotlib.lines.Line2D at 0x7fd2dc414100>]

# %%
plt.plot(x, y, 'ro--')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd2dc36ad00>,
#  <matplotlib.lines.Line2D at 0x7fd2dc36ad60>]

# %%
plt.plot(x, y, color='green')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd2dc34f9d0>,
#  <matplotlib.lines.Line2D at 0x7fd2dc34fac0>]

# %%
plt.plot(x, y, color='hotpink', marker = 'o', linestyle='dashed', linewidth=2, markersize=12)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd2dbcd8fa0>,
#  <matplotlib.lines.Line2D at 0x7fd2dbce4070>]

# %%
print(x)
y
# Out:
# [1, 2, 3]
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
plt.plot(x, y[:, 0], 'ro')
plt.plot(x, y[:, 1], 'bo')

# %%
plt.plot(x, y, '|:m')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd2dc3c9d90>,
#  <matplotlib.lines.Line2D at 0x7fd2dc3c9dc0>]

# %%
import matplotlib

# %%
matplotlib.matplotlib_fname()
# Out:
# '/home/jack/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
df = pd.DataFrame({'year': [2015, 2016],
                   'month': [2, 3],
                   'day': [4, 5]})
df
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]
